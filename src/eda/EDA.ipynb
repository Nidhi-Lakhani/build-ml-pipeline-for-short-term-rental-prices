# %% [markdown]
# ### Importing libraries and data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import wandb
import pandas as pd
import ydata_profiling

# %%
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
# Out:
# wandb: Currently logged in as: nidhi-lakhani (nidhi-lakhani-natwest-group) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>C:\Users\Nidhi\Udacity\build-ml-pipeline-for-short-term-rental-prices\src\eda\wandb\run-20260227_183657-635nlci5</code>
# Syncing run <strong><a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb/runs/635nlci5' target="_blank">grateful-silence-9</a></strong> to <a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb' target="_blank">https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb/runs/635nlci5' target="_blank">https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb/runs/635nlci5</a>

# %%
artifact = run.use_artifact("sample.csv:latest")
artifact_dir = artifact.download()
# Out:
# wandb:   1 of 1 files downloaded.

# %%
csv_path = os.path.join(artifact_dir, "sample1.csv") 
df = pd.read_csv(csv_path)

# %% [markdown]
# ### Basic EDA

# %%
profile = ydata_profiling.ProfileReport(df)
# profile.to_widgets() # error - known limitation with ydata_profiling 4.x variants thus using html
profile.to_file("report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                                                                   | 0/16 [00:00<?, ?it/s]
#   6%|███████▋                                                                                                                   | 1/16 [00:00<00:03,  4.55it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:00<00:00, 16.81it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()

# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">grateful-silence-9</strong> at: <a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb/runs/635nlci5' target="_blank">https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb/runs/635nlci5</a><br> View project at: <a href='https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb' target="_blank">https://wandb.ai/nidhi-lakhani-natwest-group/nyc_airbnb</a><br>Synced 6 W&B file(s), 0 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260227_183657-635nlci5\logs</code>
